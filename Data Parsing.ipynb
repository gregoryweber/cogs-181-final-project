# %% [markdown]
# # Data Parsing and Collection

# %%
import pandas as pd
import numpy as np

# %%
HAI = pd.read_csv('SDY404-DR54_Subject_2_HAI_result.txt', sep="\t")
HAI = HAI[['Subject Accession','Subject Phenotype','Planned Visit Accession','File Detail', 'Study Time Collected','File Name']] #Important Things
HAI.head()
# Out:
#   Subject Accession       Subject Phenotype Planned Visit Accession  \
# 0         SUB120417  Older adult, not-frail                  PV3222
# 1         SUB120417  Older adult, not-frail                  PV3225
# 2         SUB120418      Older adult, frail                  PV3222
# 3         SUB120418      Older adult, frail                  PV3225
# 4         SUB120419  Older adult, pre-frail                  PV3222
#
#   File Detail  Study Time Collected                 File Name
# 0  HAI result                     0  ALL_HAI_year2.388540.txt
# 1  HAI result                    28  ALL_HAI_year2.388540.txt
# 2  HAI result                     0  ALL_HAI_year2.388515.txt
# 3  HAI result                    28  ALL_HAI_year2.388515.txt
# 4  HAI result                     0  ALL_HAI_year2.388540.txt

# %% [markdown]
# #### DESIRABLE PARAMETERS:
# **Subject Phenotype:** Younger Adult \
# **Planned Visit Accession:** PV3225 (Later Time Point)

# %%
HAI = HAI.loc[HAI['Subject Phenotype'] == 'Younger adult']
HAI = HAI.loc[HAI['Planned Visit Accession'] == 'PV3225']
HAI.head()
# Out:
#    Subject Accession Subject Phenotype Planned Visit Accession File Detail  \
# 7          SUB120420     Younger adult                  PV3225  HAI result
# 13         SUB120423     Younger adult                  PV3225  HAI result
# 53         SUB120444     Younger adult                  PV3225  HAI result
# 55         SUB120445     Younger adult                  PV3225  HAI result
# 57         SUB120446     Younger adult                  PV3225  HAI result
#
#     Study Time Collected                 File Name
# 7                     28  ALL_HAI_year2.388515.txt
# 13                    28  ALL_HAI_year2.388540.txt
# 53                    28  ALL_HAI_year2.388540.txt
# 55                    28  ALL_HAI_year2.388515.txt
# 57                    28  ALL_HAI_year2.388515.txt

# %%
display(HAI['File Name'].unique())
# Out:
# array(['ALL_HAI_year2.388515.txt', 'ALL_HAI_year2.388540.txt'],
#       dtype=object)

# %% [markdown]
# ### Flow Data Processing

# %%
WSP = pd.read_csv('SDY404-DR54_Subject_2_Flow_cytometry_workspace.txt', sep="\t")
WSP = WSP[['Subject Accession','Subject Phenotype','Planned Visit Accession','File Detail','File Name']] #Important Things
WSP.head()
# Out:
#   Subject Accession       Subject Phenotype Planned Visit Accession  \
# 0         SUB120417  Older adult, not-frail                  PV3222
# 1         SUB120417  Older adult, not-frail                  PV3222
# 2         SUB120417  Older adult, not-frail                  PV3222
# 3         SUB120417  Older adult, not-frail                  PV3222
# 4         SUB120417  Older adult, not-frail                  PV3222
#
#                 File Detail                           File Name
# 0  Flow cytometry workspace           Panel_L1_Run_1.804538.wsp
# 1  Flow cytometry workspace   Panel_P2_Run_1-regated.804546.wsp
# 2  Flow cytometry workspace  Panel_P13_Run_1-regated.804545.wsp
# 3  Flow cytometry workspace       Panel_P9-P10_Run_1.804544.wsp
# 4  Flow cytometry workspace                 Panel P1.804543.wsp

# %%
FCS = pd.read_csv('SDY404-DR54_Subject_2_Flow_cytometry_result.txt', sep="\t")
FCS = FCS[['Subject Accession','Subject Phenotype','Planned Visit Accession','File Detail','File Name']] #Important Things
FCS.head()
# Out:
#   Subject Accession       Subject Phenotype Planned Visit Accession  \
# 0         SUB120417  Older adult, not-frail                  PV3222
# 1         SUB120417  Older adult, not-frail                  PV3222
# 2         SUB120417  Older adult, not-frail                  PV3222
# 3         SUB120417  Older adult, not-frail                  PV3222
# 4         SUB120417  Older adult, not-frail                  PV3222
#
#              File Detail                                          File Name
# 0  Flow cytometry result  Panel_P13_A10_P13_110191_PBMC_10112011_A10.578...
# 1  Flow cytometry result  Panel_P9_A1_P9_110191_PBMC_10112011_A01.578824...
# 2  Flow cytometry result  Panel_P2_A7_P2_110191_PBMC_10112011_A07.579100...
# 3  Flow cytometry result  Panel_L2_A4_L2_110191_PBMC_10112011_A04.579270...
# 4  Flow cytometry result  Panel_L1_A1_L1_110191_PBMC_10112011_A01.579376...

# %% [markdown]
# #### DESIRABLE PARAMETERS:
# **Subject Phenotype:** Younger Adult \
# **Planned Visit Accession:** PV3222 (Pre-Vaccination Point)

# %%
WSP = WSP.loc[WSP['Subject Phenotype'] == 'Younger adult']
WSP = WSP.loc[WSP['Planned Visit Accession'] == 'PV3222']
display(WSP.head())
# Out:
#     Subject Accession Subject Phenotype Planned Visit Accession  \
# 111         SUB120420     Younger adult                  PV3222
# 112         SUB120420     Younger adult                  PV3222
# 113         SUB120420     Younger adult                  PV3222
# 114         SUB120420     Younger adult                  PV3222
# 115         SUB120420     Younger adult                  PV3222
#
#                   File Detail                              File Name
# 111  Flow cytometry workspace              Panel_L1_Run_2.804556.wsp
# 112  Flow cytometry workspace              Panel P2 Run 2.804564.wsp
# 113  Flow cytometry workspace     Panel_P13_Run_2-regated.804563.wsp
# 114  Flow cytometry workspace  Panel_P9-P10_Run_2-regated.804562.wsp
# 115  Flow cytometry workspace              Panel P1 Run 2.804561.wsp

# %%
FCS = FCS.loc[FCS['Subject Phenotype'] == 'Younger adult']
FCS = FCS.loc[FCS['Planned Visit Accession'] == 'PV3222']
display(FCS.head())
FCS.shape
# Out:
#     Subject Accession Subject Phenotype Planned Visit Accession  \
# 120         SUB120420     Younger adult                  PV3222
# 121         SUB120420     Younger adult                  PV3222
# 122         SUB120420     Younger adult                  PV3222
# 123         SUB120420     Younger adult                  PV3222
# 124         SUB120420     Younger adult                  PV3222
#
#                File Detail                                          File Name
# 120  Flow cytometry result  Panel_L2_A4_L2_110194_PBMC_10112011_A04.578338...
# 121  Flow cytometry result  Panel_L4_B_Cells_A1_L4_110194_PBMC_10112011_A0...
# 122  Flow cytometry result  Panel_L3_A7_L3_110194_PBMC_10112011_A07.578627...
# 123  Flow cytometry result  Panel_P9_A1_P9_110194_PBMC_10112011_A01.578763...
# 124  Flow cytometry result  Panel_P13_A10_P13_110194_PBMC_10112011_A10.578...
# (210, 5)

# %% [markdown]
# #### For Downloading Purposes

# %%
#WSP Files
wsps = np.sort(WSP['File Name'].unique())
display(wsps)
# Out:
# array(['Panel L2 Run 7.804602.wsp', 'Panel L2 Run 8.804611.wsp',
#        'Panel P1 Run 2.804561.wsp', 'Panel P1 Run 4b.804579.wsp',
#        'Panel P1 Run 5b.804588.wsp', 'Panel P1 Run 6.804597.wsp',
#        'Panel P1 Run 7.804606.wsp', 'Panel P1 Run 8.804615.wsp',
#        'Panel P1.804543.wsp', 'Panel P2 Run 2.804564.wsp',
#        'Panel P9-P10 Run 6.804598.wsp', 'Panel_L1_Run_1.804538.wsp',
#        'Panel_L1_Run_2.804556.wsp', 'Panel_L1_Run_4.804574.wsp',
#        'Panel_L1_Run_5.804583.wsp', 'Panel_L1_Run_6.804592.wsp',
#        'Panel_L1_Run_7-regated.804601.wsp',
#        'Panel_L1_Run_8-regated.804610.wsp',
#        'Panel_L2_Run_1-regated.804539.wsp',
#        'Panel_L2_Run_2-regated.804557.wsp',
#        'Panel_L2_Run_4-regated.804575.wsp',
#        'Panel_L2_Run_5-regated.804584.wsp',
#        'Panel_L2_Run_6-regated.804593.wsp', 'Panel_L3_Run_1.804540.wsp',
#        'Panel_L3_Run_2.804558.wsp', 'Panel_L3_Run_4.804576.wsp',
#        'Panel_L3_Run_5.804585.wsp', 'Panel_L3_Run_6.804594.wsp',
#        'Panel_L3_Run_7.804603.wsp', 'Panel_L3_Run_8.804612.wsp',
#        'Panel_L4_Run_1-regated.804541.wsp',
#        'Panel_L4_Run_2-regated.804559.wsp',
#        'Panel_L4_Run_4-regated.804577.wsp',
#        'Panel_L4_Run_5-regated.804586.wsp',
#        'Panel_L4_Run_6-regated.804595.wsp',
#        'Panel_L4_Run_7-regated.804604.wsp',
#        'Panel_L4_Run_8-regated.804613.wsp',
#        'Panel_P13_Run_1-regated.804545.wsp',
#        'Panel_P13_Run_2-regated.804563.wsp',
#        'Panel_P13_Run_4-regated.804581.wsp',
#        'Panel_P13_Run_5-regated.804590.wsp',
#        'Panel_P13_Run_6-regated.804599.wsp',
#        'Panel_P13_Run_7-regated.804608.wsp',
#        'Panel_P13_Run_8-regated.804617.wsp',
#        'Panel_P2_Run_1-regated.804546.wsp',
#        'Panel_P2_Run_4-regated.804582.wsp',
#        'Panel_P2_Run_5-regated.804591.wsp',
#        'Panel_P2_Run_6-regated.804600.wsp',
#        'Panel_P2_Run_7-regated.804609.wsp',
#        'Panel_P2_Run_8-regated.804618.wsp',
#        'Panel_P9-P10_Run_1.804544.wsp',
#        'Panel_P9-P10_Run_2-regated.804562.wsp',
#        'Panel_P9-P10_Run_4-regated.804580.wsp',
#        'Panel_P9-P10_Run_5-regated.804589.wsp',
#        'Panel_P9-P10_Run_7-regated.804607.wsp',
#        'Panel_P9-P10_Run_8-regated.804616.wsp',
#        'Yr2 Run 1 Panel L5.804542.wsp', 'Yr2 Run 2 Panel L5.804560.wsp',
#        'Yr2 Run 4 Panel L5.804578.wsp', 'Yr2 Run 5 Panel L5.804587.wsp',
#        'Yr2 Run 6 Panel L5.804596.wsp', 'Yr2 Run 7 Panel L5.804605.wsp',
#        'Yr2 Run 8 Panel L5.804614.wsp'], dtype=object)

# %%
#FCS Files
fcss = np.sort(FCS['File Name'].unique())
display(fcss)
# Out:
# array(['Panel_L1_A1_L1_110194_PBMC_10112011_A01.580227.fcs',
#        'Panel_L1_A1_L1_110244_PBMC_10172011_A01.579604.fcs',
#        'Panel_L1_A1_L1_110257_PBMC_10172011_A01.580299.fcs',
#        'Panel_L1_A1_L1_110267_PBMC_10172011_A01.579602.fcs',
#        'Panel_L1_A2_L1_110197_PBMC_10112011_A02.579447.fcs',
#        'Panel_L1_A2_L1_110250_PBMC_10172011_A02.579307.fcs',
#        'Panel_L1_A2_L1_110260_PBMC_10172011_A02.578398.fcs',
#        'Panel_L1_A2_L1_110271_PBMC_10172011_A02.579258.fcs',
#        'Panel_L1_A3_L1_110243_PBMC_10172011_A03.578999.fcs',
#        'Panel_L1_A3_L1_110256_PBMC_10172011_A03.579670.fcs',
#        'Panel_L1_A3_L1_110265_PBMC_10172011_A03.578294.fcs',
#        'Panel_L1_E1_L1_110248_PBMC_10172011_E01.578572.fcs',
#        'Panel_L1_E1_L1_110258_PBMC_10172011_E01.579967.fcs',
#        'Panel_L1_E1_L1_110268_PBMC_10172011_E01.578748.fcs',
#        'Panel_L1_E2_L1_110255_PBMC_10172011_E02.580138.fcs',
#        'Panel_L1_E2_L1_110272_PBMC_10172011_E02.578501.fcs',
#        'Panel_L1_E3_L1_110247_PBMC_10172011_E03.580335.fcs',
#        'Panel_L1_E3_L1_110249_PBMC_10172011_E03.579792.fcs',
#        'Panel_L1_E3_L1_110259_PBMC_10172011_E03.578407.fcs',
#        'Panel_L1_E3_L1_110269_PBMC_10172011_E03.579084.fcs',
#        'Panel_L1_E3_L1_110270_PBMC_10172011_E03.579624.fcs',
#        'Panel_L2_A4_L2_110194_PBMC_10112011_A04.578338.fcs',
#        'Panel_L2_A4_L2_110244_PBMC_10172011_A04.579907.fcs',
#        'Panel_L2_A4_L2_110257_PBMC_10172011_A04.580144.fcs',
#        'Panel_L2_A4_L2_110267_PBMC_10172011_A04.579632.fcs',
#        'Panel_L2_A5_L2_110197_PBMC_10112011_A05.578782.fcs',
#        'Panel_L2_A5_L2_110250_PBMC_10172011_A05.580028.fcs',
#        'Panel_L2_A5_L2_110260_PBMC_10172011_A05.579611.fcs',
#        'Panel_L2_A5_L2_110271_PBMC_10172011_A05.579748.fcs',
#        'Panel_L2_A6_L2_110243_PBMC_10172011_A06.578424.fcs',
#        'Panel_L2_A6_L2_110256_PBMC_10172011_A06.578553.fcs',
#        'Panel_L2_A6_L2_110265_PBMC_10172011_A06.579508.fcs',
#        'Panel_L2_E4_L2_110248_PBMC_10172011_E04.579938.fcs',
#        'Panel_L2_E4_L2_110258_PBMC_10172011_E04.579648.fcs',
#        'Panel_L2_E4_L2_110268_PBMC_10172011_E04.578619.fcs',
#        'Panel_L2_E5_L2_110255_PBMC_10172011_E05.578746.fcs',
#        'Panel_L2_E5_L2_110272_PBMC_10172011_E05.578806.fcs',
#        'Panel_L2_E6_L2_110247_PBMC_10172011_E06.579729.fcs',
#        'Panel_L2_E6_L2_110249_PBMC_10172011_E06.578361.fcs',
#        'Panel_L2_E6_L2_110259_PBMC_10172011_E06.579505.fcs',
#        'Panel_L2_E6_L2_110269_PBMC_10172011_E06.579220.fcs',
#        'Panel_L2_E6_L2_110270_PBMC_10172011_E06.579068.fcs',
#        'Panel_L3_A7_L3_110194_PBMC_10112011_A07.578627.fcs',
#        'Panel_L3_A7_L3_110244_PBMC_10172011_A07.578470.fcs',
#        'Panel_L3_A7_L3_110257_PBMC_10172011_A07.578568.fcs',
#        'Panel_L3_A7_L3_110267_PBMC_10172011_A07.579076.fcs',
#        'Panel_L3_A8_L3_110197_PBMC_10112011_A08.578790.fcs',
#        'Panel_L3_A8_L3_110250_PBMC_10172011_A08.580155.fcs',
#        'Panel_L3_A8_L3_110260_PBMC_10172011_A08.578890.fcs',
#        'Panel_L3_A8_L3_110271_PBMC_10172011_A08.579703.fcs',
#        'Panel_L3_A9_L3_110243_PBMC_10172011_A09.579137.fcs',
#        'Panel_L3_A9_L3_110256_PBMC_10172011_A09.580187.fcs',
#        'Panel_L3_A9_L3_110265_PBMC_10172011_A09.579112.fcs',
#        'Panel_L3_E7_L3_110248_PBMC_10172011_E07.579156.fcs',
#        'Panel_L3_E7_L3_110258_PBMC_10172011_E07.579762.fcs',
#        'Panel_L3_E7_L3_110268_PBMC_10172011_E07.579311.fcs',
#        'Panel_L3_E8_L3_110255_PBMC_10172011_E08.578997.fcs',
#        'Panel_L3_E8_L3_110272_PBMC_10172011_E08.578268.fcs',
#        'Panel_L3_E9_L3_110247_PBMC_10172011_E09.578609.fcs',
#        'Panel_L3_E9_L3_110249_PBMC_10172011_E09.579873.fcs',
#        'Panel_L3_E9_L3_110259_PBMC_10172011_E09.578516.fcs',
#        'Panel_L3_E9_L3_110269_PBMC_10172011_E09.580122.fcs',
#        'Panel_L3_E9_L3_110270_PBMC_10172011_E09.580280.fcs',
#        'Panel_L4_B_Cells_A1_L4_110194_PBMC_10112011_A01.578484.fcs',
#        'Panel_L4_B_Cells_A1_L4_110244_PBMC_10172011_A01.578800.fcs',
#        'Panel_L4_B_Cells_A1_L4_110257_PBMC_10172011_A01.579550.fcs',
#        'Panel_L4_B_Cells_A1_L4_110267_PBMC_10172011_A01.578653.fcs',
#        'Panel_L4_B_Cells_A2_L4_110197_PBMC_10112011_A02.579074.fcs',
#        'Panel_L4_B_Cells_A2_L4_110250_PBMC_10172011_A02.579943.fcs',
#        'Panel_L4_B_Cells_A2_L4_110260_PBMC_10172011_A02.579081.fcs',
#        'Panel_L4_B_Cells_A2_L4_110271_PBMC_10172011_A02.580082.fcs',
#        'Panel_L4_B_Cells_A3_L4_110243_PBMC_10172011_A03.578928.fcs',
#        'Panel_L4_B_Cells_A3_L4_110256_PBMC_10172011_A03.578749.fcs',
#        'Panel_L4_B_Cells_A3_L4_110265_PBMC_10172011_A03.578477.fcs',
#        'Panel_L4_B_Cells_E1_L4_110248_PBMC_10172011_E01.580115.fcs',
#        'Panel_L4_B_Cells_E1_L4_110258_PBMC_10172011_E01.578555.fcs',
#        'Panel_L4_B_Cells_E1_L4_110268_PBMC_10172011_E01.579622.fcs',
#        'Panel_L4_B_Cells_E2_L4_110255_PBMC_10172011_E02.579687.fcs',
#        'Panel_L4_B_Cells_E2_L4_110272_PBMC_10172011_E02.578680.fcs',
#        'Panel_L4_B_Cells_E3_L4_110247_PBMC_10172011_E03.578340.fcs',
#        'Panel_L4_B_Cells_E3_L4_110249_PBMC_10172011_E03.579980.fcs',
#        'Panel_L4_B_Cells_E3_L4_110259_PBMC_10172011_E03.580271.fcs',
#        'Panel_L4_B_Cells_E3_L4_110269_PBMC_10172011_E03.580308.fcs',
#        'Panel_L4_B_Cells_E3_L4_110270_PBMC_10172011_E03.578859.fcs',
#        'Panel_L5_MonoNKDC_A4_L5_110194_PBMC_10112011_A04.579267.fcs',
#        'Panel_L5_MonoNKDC_A4_L5_110244_PBMC_10172011_A04.578551.fcs',
#        'Panel_L5_MonoNKDC_A4_L5_110257_PBMC_10172011_A04.578610.fcs',
#        'Panel_L5_MonoNKDC_A4_L5_110267_PBMC_10172011_A04.580205.fcs',
#        'Panel_L5_MonoNKDC_A5_L5_110197_PBMC_10112011_A05.580003.fcs',
#        'Panel_L5_MonoNKDC_A5_L5_110250_PBMC_10172011_A05.579323.fcs',
#        'Panel_L5_MonoNKDC_A5_L5_110260_PBMC_10172011_A05.579194.fcs',
#        'Panel_L5_MonoNKDC_A5_L5_110271_PBMC_10172011_A05.578771.fcs',
#        'Panel_L5_MonoNKDC_A6_L5_110243_PBMC_10172011_A06.579994.fcs',
#        'Panel_L5_MonoNKDC_A6_L5_110256_PBMC_10172011_A06.578413.fcs',
#        'Panel_L5_MonoNKDC_A6_L5_110265_PBMC_10172011_A06.578955.fcs',
#        'Panel_L5_MonoNKDC_E4_L5_110248_PBMC_10172011_E04.579886.fcs',
#        'Panel_L5_MonoNKDC_E4_L5_110258_PBMC_10172011_E04.578977.fcs',
#        'Panel_L5_MonoNKDC_E4_L5_110268_PBMC_10172011_E04.578880.fcs',
#        'Panel_L5_MonoNKDC_E5_L5_110255_PBMC_10172011_E05.579047.fcs',
#        'Panel_L5_MonoNKDC_E5_L5_110272_PBMC_10172011_E05.579102.fcs',
#        'Panel_L5_MonoNKDC_E6_L5_110247_PBMC_10172011_E06.579704.fcs',
#        'Panel_L5_MonoNKDC_E6_L5_110249_PBMC_10172011_E06.579610.fcs',
#        'Panel_L5_MonoNKDC_E6_L5_110259_PBMC_10172011_E06.579377.fcs',
#        'Panel_L5_MonoNKDC_E6_L5_110269_PBMC_10172011_E06.579443.fcs',
#        'Panel_L5_MonoNKDC_E6_L5_110270_PBMC_10172011_E06.579482.fcs',
#        'Panel_P10_A4_P10_110194_PBMC_10112011_A04.580224.fcs',
#        'Panel_P10_A4_P10_110244_PBMC_10172011_A04.579906.fcs',
#        'Panel_P10_A4_P10_110257_PBMC_10172011_A04.580102.fcs',
#        'Panel_P10_A4_P10_110267_PBMC_10172011_A04.579101.fcs',
#        'Panel_P10_A5_P10_110197_PBMC_10112011_A05.579268.fcs',
#        'Panel_P10_A5_P10_110250_PBMC_10172011_A05.580402.fcs',
#        'Panel_P10_A5_P10_110260_PBMC_10172011_A05.579228.fcs',
#        'Panel_P10_A5_P10_110271_PBMC_10172011_A05.579996.fcs',
#        'Panel_P10_A6_P10_110243_PBMC_10172011_A06.579380.fcs',
#        'Panel_P10_A6_P10_110256_PBMC_10172011_A06.578738.fcs',
#        'Panel_P10_A6_P10_110265_PBMC_10172011_A06.579586.fcs',
#        'Panel_P10_E4_P10_110248_PBMC_10172011_E04.578591.fcs',
#        'Panel_P10_E4_P10_110258_PBMC_10172011_E04.578764.fcs',
#        'Panel_P10_E4_P10_110268_PBMC_10172011_E04.580152.fcs',
#        'Panel_P10_E5_P10_110255_PBMC_10172011_E05.580354.fcs',
#        'Panel_P10_E5_P10_110272_PBMC_10172011_E05.579432.fcs',
#        'Panel_P10_E6_P10_110247_PBMC_10172011_E06.578460.fcs',
#        'Panel_P10_E6_P10_110249_PBMC_10172011_E06.580079.fcs',
#        'Panel_P10_E6_P10_110259_PBMC_10172011_E06.579050.fcs',
#        'Panel_P10_E6_P10_110269_PBMC_10172011_E06.578832.fcs',
#        'Panel_P10_E6_P10_110270_PBMC_10172011_E06.579075.fcs',
#        'Panel_P13_A10_P13_110194_PBMC_10112011_A10.578778.fcs',
#        'Panel_P13_A10_P13_110244_PBMC_10172011_A10.579584.fcs',
#        'Panel_P13_A10_P13_110257_PBMC_10172011_A10.578364.fcs',
#        'Panel_P13_A10_P13_110267_PBMC_10172011_A10.579204.fcs',
#        'Panel_P13_A11_P13_110197_PBMC_10112011_A11.579968.fcs',
#        'Panel_P13_A11_P13_110250_PBMC_10172011_A11.579856.fcs',
#        'Panel_P13_A11_P13_110260_PBMC_10172011_A11.579794.fcs',
#        'Panel_P13_A11_P13_110271_PBMC_10172011_A11.579567.fcs',
#        'Panel_P13_A12_P13_110243_PBMC_10172011_A12.579941.fcs',
#        'Panel_P13_A12_P13_110256_PBMC_10172011_A12.578362.fcs',
#        'Panel_P13_A12_P13_110265_PBMC_10172011_A12.580107.fcs',
#        'Panel_P13_E10_P13_110248_PBMC_10172011_E10.578922.fcs',
#        'Panel_P13_E10_P13_110258_PBMC_10172011_E10.578602.fcs',
#        'Panel_P13_E10_P13_110268_PBMC_10172011_E10.578379.fcs',
#        'Panel_P13_E11_P13_110255_PBMC_10172011_E11.579169.fcs',
#        'Panel_P13_E11_P13_110272_PBMC_10172011_E11.578898.fcs',
#        'Panel_P13_E12_P13_110247_PBMC_10172011_E12.579293.fcs',
#        'Panel_P13_E12_P13_110249_PBMC_10172011_E12.579126.fcs',
#        'Panel_P13_E12_P13_110259_PBMC_10172011_E12.578499.fcs',
#        'Panel_P13_E12_P13_110269_PBMC_10172011_E12.579177.fcs',
#        'Panel_P13_E12_P13_110270_PBMC_10172011_E12.578988.fcs',
#        'Panel_P1_A10_P1_110194_PBMC_10112011_A10.579164.fcs',
#        'Panel_P1_A10_P1_110244_PBMC_10172011_A10.579497.fcs',
#        'Panel_P1_A10_P1_110257_PBMC_10172011_A10.579308.fcs',
#        'Panel_P1_A10_P1_110267_PBMC_10172011_A10.580112.fcs',
#        'Panel_P1_A11_P1_110197_PBMC_10112011_A11.579080.fcs',
#        'Panel_P1_A11_P1_110250_PBMC_10172011_A11.578537.fcs',
#        'Panel_P1_A11_P1_110260_PBMC_10172011_A11.579260.fcs',
#        'Panel_P1_A11_P1_110271_PBMC_10172011_A11.579572.fcs',
#        'Panel_P1_A12_P1_110243_PBMC_10172011_A12.580311.fcs',
#        'Panel_P1_A12_P1_110256_PBMC_10172011_A12.579090.fcs',
#        'Panel_P1_A12_P1_110265_PBMC_10172011_A12.578612.fcs',
#        'Panel_P1_E10_P1_110248_PBMC_10172011_E10.579463.fcs',
#        'Panel_P1_E10_P1_110258_PBMC_10172011_E10.578455.fcs',
#        'Panel_P1_E10_P1_110268_PBMC_10172011_E10.579997.fcs',
#        'Panel_P1_E11_P1_110255_PBMC_10172011_E11.578264.fcs',
#        'Panel_P1_E11_P1_110272_PBMC_10172011_E11.578681.fcs',
#        'Panel_P1_E12_P1_110247_PBMC_10172011_E12.579389.fcs',
#        'Panel_P1_E12_P1_110249_PBMC_10172011_E12.579665.fcs',
#        'Panel_P1_E12_P1_110259_PBMC_10172011_E12.579691.fcs',
#        'Panel_P1_E12_P1_110269_PBMC_10172011_E12.578694.fcs',
#        'Panel_P1_E12_P1_110270_PBMC_10172011_E12.580073.fcs',
#        'Panel_P2_A7_P2_110194_PBMC_10112011_A07.579256.fcs',
#        'Panel_P2_A7_P2_110244_PBMC_10172011_A07.579920.fcs',
#        'Panel_P2_A7_P2_110257_PBMC_10172011_A07.580002.fcs',
#        'Panel_P2_A7_P2_110267_PBMC_10172011_A07.579901.fcs',
#        'Panel_P2_A8_P2_110197_PBMC_10112011_A08.579619.fcs',
#        'Panel_P2_A8_P2_110250_PBMC_10172011_A08.579479.fcs',
#        'Panel_P2_A8_P2_110260_PBMC_10172011_A08.579237.fcs',
#        'Panel_P2_A8_P2_110271_PBMC_10172011_A08.580021.fcs',
#        'Panel_P2_A9_P2_110243_PBMC_10172011_A09.578865.fcs',
#        'Panel_P2_A9_P2_110256_PBMC_10172011_A09.579779.fcs',
#        'Panel_P2_A9_P2_110265_PBMC_10172011_A09.580401.fcs',
#        'Panel_P2_E7_P2_110248_PBMC_10172011_E07.580135.fcs',
#        'Panel_P2_E7_P2_110258_PBMC_10172011_E07.578539.fcs',
#        'Panel_P2_E7_P2_110268_PBMC_10172011_E07.578514.fcs',
#        'Panel_P2_E8_P2_110255_PBMC_10172011_E08.578878.fcs',
#        'Panel_P2_E8_P2_110272_PBMC_10172011_E08.579585.fcs',
#        'Panel_P2_E9_P2_110247_PBMC_10172011_E09.578528.fcs',
#        'Panel_P2_E9_P2_110249_PBMC_10172011_E09.580170.fcs',
#        'Panel_P2_E9_P2_110259_PBMC_10172011_E09.579580.fcs',
#        'Panel_P2_E9_P2_110269_PBMC_10172011_E09.579057.fcs',
#        'Panel_P2_E9_P2_110270_PBMC_10172011_E09.579607.fcs',
#        'Panel_P9_A1_P9_110194_PBMC_10112011_A01.578763.fcs',
#        'Panel_P9_A1_P9_110244_PBMC_10172011_A01.579668.fcs',
#        'Panel_P9_A1_P9_110257_PBMC_10172011_A01.579405.fcs',
#        'Panel_P9_A1_P9_110267_PBMC_10172011_A01.580181.fcs',
#        'Panel_P9_A2_P9_110197_PBMC_10112011_A02.579640.fcs',
#        'Panel_P9_A2_P9_110250_PBMC_10172011_A02.578545.fcs',
#        'Panel_P9_A2_P9_110260_PBMC_10172011_A02.580029.fcs',
#        'Panel_P9_A2_P9_110271_PBMC_10172011_A02.580085.fcs',
#        'Panel_P9_A3_P9_110243_PBMC_10172011_A03.579525.fcs',
#        'Panel_P9_A3_P9_110256_PBMC_10172011_A03.579442.fcs',
#        'Panel_P9_A3_P9_110265_PBMC_10172011_A03.579869.fcs',
#        'Panel_P9_E1_P9_110248_PBMC_10172011_E01.579227.fcs',
#        'Panel_P9_E1_P9_110258_PBMC_10172011_E01.579305.fcs',
#        'Panel_P9_E1_P9_110268_PBMC_10172011_E01.580360.fcs',
#        'Panel_P9_E2_P9_110255_PBMC_10172011_E02.579279.fcs',
#        'Panel_P9_E2_P9_110272_PBMC_10172011_E02.578987.fcs',
#        'Panel_P9_E3_P9_110247_PBMC_10172011_E03.579847.fcs',
#        'Panel_P9_E3_P9_110249_PBMC_10172011_E03.580285.fcs',
#        'Panel_P9_E3_P9_110259_PBMC_10172011_E03.579949.fcs',
#        'Panel_P9_E3_P9_110269_PBMC_10172011_E03.579018.fcs',
#        'Panel_P9_E3_P9_110270_PBMC_10172011_E03.578826.fcs'], dtype=object)

# %% [markdown]
# ## TODO: File Collection

# %%
import os
import bokeh
from bokeh.plotting import show
import pandas as pd

import flowkit as fk

bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a42d5870-8c10-42b8-b52a-5e5130c2e210">Loading BokehJS ...</span>
#     </div>

# %%
#Finding the FCS files you want
def findFCS(wsp):
    workspace = fk.Workspace(wsp, ignore_missing_files=True, find_fcs_files_from_wsp=True)
    allFiles = workspace.get_sample_ids()
    needFiles = []
    for f in allFiles:
        if f in fcss:
            needFiles.append(f)
            fcss.remove(f)
    return needFiles

# %%
#Download FCS Files
def getFCS(needFiles):
    #weeeeeeeeeeeee
    return

# %%
#Analyzing and Parsing Gates
fcs_filepath = ...
def analyzeWSP(wsp, needFiles):
    workspace = fk.Workspace(wsp, fcs_samples = fcs_filepath, ignore_missing_files=True)
    for f in needFiles:
        sample = workspace.analyze_samples(sample_id = f)
        #do stuff to get the stuff you want
        #talk with greg on how we want data structured -- extract first three gates for "preprocessing." keep in mind gate names will change
        #save to github repository under same name but with .csv

# %%
def deleteFiles(wsp, needFiles):
    #delete for space :)
    return

# %% [markdown]
# ## TODO: Add HAI Titer
# (and day if possible -- check if its all day 28) to FCS File dataframe. Change FCS File names to .csv and add preprocessing column if necessary

# %%
HAI1 = pd.read_csv("ALL_HAI_year2.388515.txt", sep="\t")
HAI2 = pd.read_csv("ALL_HAI_year2.388540.txt", sep="\t")
display(HAI1.shape)
display(HAI2.shape)
display(HAI1.equals(HAI2))
HAI1.head(10)
#File Name does not matter because they're the same
# Out:
# (138, 6)
# (138, 6)
# True
#    Subject  Day   H1  H3   B Age Group
# 0   110191    0   64   8  32       Old
# 1   110191   28  128  16  32       Old
# 2   110192    0   32  16  64       Old
# 3   110192   28   32  16  64       Old
# 4   110193    0    8   8  16       Old
# 5   110193   28   16   8  16       Old
# 6   110194    0   32  16  16     Young
# 7   110194   28   64  16  16     Young
# 8   110195    0   16  16   8       Old
# 9   110195   28   64  32  32       Old

# %%
HAI = pd.read_csv("SDY404-DR54_Subject_2_HAI_result.txt", sep="\t")
HAI = HAI[['Subject Accession', 'Subject Phenotype', 'Planned Visit Accession','Study Time Collected']]
display(HAI.head())
HAI.shape
# Out:
#   Subject Accession       Subject Phenotype Planned Visit Accession  \
# 0         SUB120417  Older adult, not-frail                  PV3222
# 1         SUB120417  Older adult, not-frail                  PV3225
# 2         SUB120418      Older adult, frail                  PV3222
# 3         SUB120418      Older adult, frail                  PV3225
# 4         SUB120419  Older adult, pre-frail                  PV3222
#
#    Study Time Collected
# 0                     0
# 1                    28
# 2                     0
# 3                    28
# 4                     0
# (138, 4)

# %%
def oldyoung(x):
    if x == "Younger adult":
        return "Young"
    else:
        return "Old"

HAI['Subject Phenotype'] = HAI['Subject Phenotype'].apply(oldyoung)
HAI.rename(columns={'Subject Phenotype': 'Age Group', 'Study Time Collected': 'Day'}, inplace=True)
HAI.head(10)
# Out:
#   Subject Accession Age Group Planned Visit Accession  Day
# 0         SUB120417       Old                  PV3222    0
# 1         SUB120417       Old                  PV3225   28
# 2         SUB120418       Old                  PV3222    0
# 3         SUB120418       Old                  PV3225   28
# 4         SUB120419       Old                  PV3222    0
# 5         SUB120419       Old                  PV3225   28
# 6         SUB120420     Young                  PV3222    0
# 7         SUB120420     Young                  PV3225   28
# 8         SUB120421       Old                  PV3222    0
# 9         SUB120421       Old                  PV3225   28

# %%
df = HAI[['Age Group','Day']].eq(HAI1[['Age Group','Day']])
display(df['Age Group'].unique()) #Age Group Matches, so can drop
display(df['Day'].unique()) #Day does not match, why?
# Out:
# array([ True])
# array([ True, False])

# %%
HAI.iloc[df[df['Day'] == False].index]
# Out:
#     Subject Accession Age Group Planned Visit Accession  Day
# 61          SUB120449     Young                  PV3225   24
# 83          SUB120461     Young                  PV3225   36
# 101         SUB120470     Young                  PV3225   24
# 105         SUB120472     Young                  PV3225   32
# 115         SUB120477       Old                  PV3225   35
# 117         SUB120478       Old                  PV3225   35

# %%
HAI1.iloc[df[df['Day'] == False].index]
# Out:
#      Subject  Day    H1   H3    B Age Group
# 61    110247   28  1024  128   64     Young
# 83    110259   28   128  128   64     Young
# 101   110268   28   512   32   64     Young
# 105   110270   28   128   16  128     Young
# 115   110275   28    32    8  128       Old
# 117   110276   28   256   16   32       Old

# %%
#So day is slightly different, but otherwise probably ok to assume. HAI titer still later so probably ok. We will go based on HAI Titer Document with actual HAI data.
HAI1.drop(columns = ['Subject','Age Group'], inplace=True)
HAI.drop(columns = 'Day', inplace=True)
HAIall = HAI.join(HAI1)
HAIall
# Out:
#     Subject Accession Age Group Planned Visit Accession  Day   H1  H3   B
# 0           SUB120417       Old                  PV3222    0   64   8  32
# 1           SUB120417       Old                  PV3225   28  128  16  32
# 2           SUB120418       Old                  PV3222    0   32  16  64
# 3           SUB120418       Old                  PV3225   28   32  16  64
# 4           SUB120419       Old                  PV3222    0    8   8  16
# ..                ...       ...                     ...  ...  ...  ..  ..
# 133         SUB120486       Old                  PV3225   28   32  16  16
# 134         SUB120487       Old                  PV3222    0    8   8  64
# 135         SUB120487       Old                  PV3225   28    8   8  64
# 136         SUB120488       Old                  PV3222    0   64   8  16
# 137         SUB120488       Old                  PV3225   28   64   8  32
#
# [138 rows x 7 columns]

# %%
HAIall = HAIall.loc[HAIall['Age Group'] == 'Young']
HAIall = HAIall.loc[HAIall['Day'] == 28]
display(HAIall.head())
HAIall.shape
# Out:
#    Subject Accession Age Group Planned Visit Accession  Day    H1   H3   B
# 7          SUB120420     Young                  PV3225   28    64   16  16
# 13         SUB120423     Young                  PV3225   28   256   16  16
# 53         SUB120444     Young                  PV3225   28   512   16  32
# 55         SUB120445     Young                  PV3225   28    64    8  32
# 57         SUB120446     Young                  PV3225   28  1024  256  64
# (32, 7)

# %%
HAIall.drop(columns = ['Age Group','Planned Visit Accession','Day'], inplace = True)
HAIall.reset_index(drop=True, inplace = True)
HAIall.head()
#Y values: H1, H3, B
# Out:
#   Subject Accession    H1   H3   B
# 0         SUB120420    64   16  16
# 1         SUB120423   256   16  16
# 2         SUB120444   512   16  32
# 3         SUB120445    64    8  32
# 4         SUB120446  1024  256  64
